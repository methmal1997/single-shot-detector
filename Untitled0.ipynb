# %%
from os.path import join
from google.colab import drive

ROOT = "/content/drive"
drive.mount(ROOT)

PROJ = "My Drive/SSD Custom" # This is a custom path.
PROJECT_PATH = join(ROOT, PROJ)

# %cd ~/content
# %cd drive/My Drive/SSD Custom
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: '/root/content'
# /content
# /content/drive/My Drive/SSD Custom

# %%
! ls
# Out:
# checkpoints		    __pycache__		  tf_utils.py
# datasets		    README.md		  train_ssd_network.py
# deployment		    split_train_test.py   Untitled0.ipynb
# google_colab_example.ipynb  test_ssd_model.ipynb  visualization.py
# nets			    tf_extended		  VOC2007
# preprocessing		    tfrecords		  xmltotfrecords_conversion.py

# %%
# !git clone https://github.com/methmal1997/SSD-Tensorflow-On-Custom-Dataset
# Out:
# Cloning into 'SSD-Tensorflow-On-Custom-Dataset'...
# remote: Enumerating objects: 221, done.
# remote: Counting objects: 100% (221/221), done.
# remote: Compressing objects: 100% (169/169), done.
# remote: Total 221 (delta 54), reused 202 (delta 46), pack-reused 0
# Receiving objects: 100% (221/221), 96.41 MiB | 17.28 MiB/s, done.
# Resolving deltas: 100% (54/54), done.
# Checking out files: 100% (67/67), done.

# %%
! git-pull(1)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `1'
# /bin/bash: -c: line 0: ` git-pull(1)'

# %%
username ='methmal1997'
repositary ='single-shot-detector'
git_token='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'

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/SSD Custom/.git/

# %%
! ls -a
# Out:
# checkpoints		    __pycache__		  train_ssd_network.py
# datasets		    README.md		  Untitled0.ipynb
# deployment		    split_train_test.py   visualization.py
# .git			    test_ssd_model.ipynb  VOC2007
# google_colab_example.ipynb  tf_extended		  xmltotfrecords_conversion.py
# nets			    tfrecords
# preprocessing		    tf_utils.py

# %%
# !git add .
# !git status
# Out:
# On branch master
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	modified:   Untitled0.ipynb

# %%
# !git config --global user.email "methmaludan@gmail.com"
# !git config --global user.name "methmal1997"

# %%
# !git commit -m 'initial'
# Out:
# [master (root-commit) 24abad8] initial
#  68 files changed, 15302 insertions(+)
#  create mode 100644 README.md
#  create mode 100644 Untitled0.ipynb
#  create mode 100644 VOC2007/Annotations/sampleannotatin.xml
#  create mode 100644 VOC2007/ImageSets/test.txt
#  create mode 100644 VOC2007/ImageSets/train.txt
#  create mode 100644 VOC2007/JPEGImages/sampleimage.png
#  create mode 100644 __pycache__/dataset_utils.cpython-36.pyc
#  create mode 100644 __pycache__/pascalvoc_common.cpython-36.pyc
#  create mode 100644 __pycache__/pascalvoc_to_tfrecords.cpython-36.pyc
#  create mode 100644 __pycache__/tf_utils.cpython-36.pyc
#  create mode 100644 checkpoints/ssd_300_vgg.ckpt.zip
#  create mode 100644 datasets/__pycache__/dataset_factory.cpython-36.pyc
#  create mode 100644 datasets/__pycache__/dataset_utils.cpython-36.pyc
#  create mode 100644 datasets/__pycache__/pascalvoc_2007.cpython-36.pyc
#  create mode 100644 datasets/__pycache__/pascalvoc_common.cpython-36.pyc
# ...

# %%
# !git branch -M main

# %%
# !git remote add origin https://{git_token}@github.com/{username}/{repositary}.git
# Out:
# fatal: remote origin already exists.

# %%
# !git push -u origin main
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address
